# %%
data=loadnc('/media/moflaher/My Book/cages/sfm6_musq2_old_cages/output/')
data=ncdatasort(data)
cages=np.genfromtxt('/media/moflaher/My Book/cages/sfm6_musq2_old_cages/input/sfm6_musq2_cage.dat',skiprows=1)
cages=(cages[:,0]-1).astype(int)
region=regions('musq_cage')
newr=region['region']

# %%
figsize(32,24)
plt.triplot(data['trigrid'])
plt.plot(data['uvnodell'][cages,0],data['uvnodell'][cages,1],'*')
plt.axis(newr)
# Out:
# array([-66.925, -66.8  ,  45.   ,  45.075])
